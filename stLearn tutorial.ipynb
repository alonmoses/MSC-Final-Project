# %%
pip install python_igraph-0.9.8-py3-none-any.whl
# Out:
# Processing c:\users\alon2\google drive\studies 2\year 2\final project\project_git_repo\python_igraph-0.9.8-py3-none-any.whl
# ...
# python-igraph is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python_louvain-0.15-py3-none-any.whl
# Out:
# Processing c:\users\alon2\google drive\studies 2\year 2\final project\project_git_repo\python_louvain-0.15-py3-none-any.whl
# ...
# python-louvain is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall stlearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping stlearn as it is not installed.

# %%
pip install -U stlearn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\alon2\\anaconda3\\envs\\FPST\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#   Using cached stlearn-0.3.2-py2.py3-none-any.whl (116 kB)
# ...
#   Using cached bokeh-2.3.0.tar.gz (10.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached tensorflow-2.4.0-cp38-cp38-win_amd64.whl (370.7 MB)
# ...
#   Using cached scanpy-1.7.1-py3-none-any.whl (10.3 MB)
# ...
#   Using cached fa2-0.3.5.tar.gz (435 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
# ...

# %%
pip uninstall tables
pip install tables
# Out:
#   File "C:\Users\alon2\AppData\Local\Temp/ipykernel_14304/359098314.py", line 1
#     pip uninstall tables
#         ^
# SyntaxError: invalid syntax
